# %% [markdown]
# <a href="https://colab.research.google.com/github/RobAldous/My-Python-Basics-Repository/blob/main/Day_1_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello\nWorld")   # Expected:
                       # Hello
                       # World
# Out:
# Hello
# World

# %%
print("C
ew folder\\test.txt")   # Expected: C:
ew_folder\\test.txt
# Out:
#   File "/tmp/ipykernel_2594/540766777.py", line 1
#     print("C:
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('"She said:"Python is fun!"')
# Out:
# "She said:"Python is fun!"

# %%
print("C:\new_folder\\test.txt")
# Out:
# C:
# ew_folder\test.txt

# %% [markdown]
# # Print Function

# %%
# !python --version
# Out:
# Python 3.12.13

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Oh boy!")
# Out:
# Oh boy!

# %%
print("Can I Program?")
# Out:
# Can I Program?

# %%
print("not working")
# Out:
# not working

# %%
print("my dad's favourite car is a Ford")
# Out:
# my dad's favourite car is a Ford

# %%
print("3.14" * 2)
# Out:
# 3.143.14

# %%
print(3.14*2)
# Out:
# 6.28

# %%
print("This is going to be a very long line to see\nhow it shows once you have executed")
# Out:
# This is going to be a very long line to see
# how it shows once you have executed

# %%
print("Rob A 56 UK")
# Out:
# Rob A 56 UK

# %%
print("Mr R Aldous")
# Out:
# Mr R Aldous

# %%
print(1,2,3) #multiple argument

print("1"+"2"+"3") #concat operator

print(1 + 2 + 3) # addition operator
# Out:
# 1 2 3
# 123
# 6

# %%
print("C:\\Users\\Yusuf\\Documents")
# Out:
# C:\Users\Yusuf\Documents

# %%
print(" " + " ")

# %%
print(2543//59)
# Out:
# 43

# %%
print("435 minutes is", 435//60, "hours and", 435%60, "minutes")
# Out:
# 435 minutes is 7 hours and 15 minutes

# %%
print("The square root of", 100, "is", 10)
# Out:
# The square root of 100 is 10

# %%
print(17//4)
# Out:
# 4

# %%
print(17%4)
# Out:
# 1

# %%
print(100//10)
# Out:
# 10

# %%
print(1000**0.5)
# Out:
# 31.622776601683793

# %%
myname = "Rob"

# %%
mylocation = "Ipswich"

# %%
input("What is your password:")
# Out:
# What is your password:1234
# '1234'

# %%
password = input("Enter password:")
# Out:
# Enter password:1234

# %%
print("This is a pence calculator.")

pound = float(input("Please enter amount in £:"))

pence = pound *100
print(pound, "is", pence, "pence.")
# Out:
# This is a pence calculator.
# Please enter amount in £:3023.21
# 3023.21 is 302321.0 pence.

# %%
num1 = float(input("Please enter first number"))
num2 = float(input ("Please enter second number"))
print("Sum of number is",(num1 + num2))
# Out:
# Please enter first number4
# Please enter second number6
# Sum of number is 10.0

# %%
input("Please enter your name"),
# Out:
# Please enter your namerob
# 'rob'

# %%
input("Please enter your age")
# Out:
# Please enter your age67
# '67'

# %%
print("Thank you for entering your details")
# Out:
# Thank you for entering your details

# %%
length = float(input("Please enter length of kitchen floor in meters"))
width = float(input("Please enter width of kitchen floor in meters"))
print("Area of kitchen floor is", (length*width))
# Out:
# Please enter length of kitchen floor in meters5.6
# Please enter width of kitchen floor in meters4
# Area of kitchen floor is 22.4

# %%
Area_to_tile = float(input("Please enter total area to tile"))
print("Total Cost",(Area_to_tile*12))
# Out:
# Please enter total area to tile15
# Total Cost 180.0

# %%
miles = float(input("Please enter number of miles "))
print("This is",(miles*1.60934),("kilometers"))
# Out:
# Please enter number of miles 5
# This is 8.0467 kilometers

# %%
kilometers = float(input("Please enter number of kilometers "))
print("This is",(kilometers/1.60934),("miles"))
# Out:
# Please enter number of kilometers 45
# This is 27.961773149241303 miles

# %%
threedigitnumber = int(input("Please enter three digits to find your luck number"))
# Out:
# Please enter three digits to find your luck number123

# %%
number = int(input("Enter a 3-digit number: "))

# Extract digits
hundreds = number // 100
tens = (number // 10) % 10
units = number % 10

# Add the digits
lucky_number = hundreds + tens + units

# Print the result
print("Your lucky number is:", lucky_number)
# Out:
# Enter a 3-digit number: 258
# Your lucky number is: 15

# %%
celcius = float(input("Please enter today's temperature in Celsius:"))
fahrenheit = (9/5) * celcius + 32
print(f"{celcius} Celcius is equal to {Fahrenheit} Fahrenheit.")
# Out:
# Please enter today's temperature in Celsius:56
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14059/177669274.py in <cell line: 0>()
#       1 celcius = float(input("Please enter today's temperature in Celsius:"))
#       2 fahrenheit = (9/5) * celcius + 32
# ----> 3 print(f"{celcius} Celcius is equal to {Fahrenheit} Fahrenheit.")
#
# NameError: name 'Fahrenheit' is not defined
